# %%
file_lis = []
with open('files.txt', 'r', encoding='utf-8') as f:
    for line in f:
        url = line.strip()
        file_name = url.split('/')[-1]
        file_lis.append(file_name)
print(file_lis)
# Out:
# ['model-00010-of-00016.safetensors', 'model-00011-of-00016.safetensors', 'model-00012-of-00016.safetensors', 'model-00013-of-00016.safetensors', 'model-00014-of-00016.safetensors', 'model-00016-of-00016.safetensors']

# %%
from modelscope.hub.file_download import model_file_download
for file_name in file_lis:
    model_dir = model_file_download(model_id='Xunzillm4cc/Xunzi-Qwen1.5-7B_chat',
                                    file_path=file_name,
                                    cache_dir='.qwen',
                                    local_dir='.qwen/Xunzillm4cc/Xunzi-Qwen1.5-7B_chat',
                                    revision='master')
    print(f"Downloaded {file_name} to {model_dir}")
{[句子1:xxx,
  实体列表[
      [实体1:xxx, 类别:xxx, 句子中index:[x,y]],
      [实体2:xxx, 类别:xxx, 句子中index:[x,y]],
      ]
  ],...
 []}
# Out:
# ...
# Downloaded model-00010-of-00016.safetensors to .qwen/Xunzillm4cc/Xunzi-Qwen1.5-7B_chat\model-00010-of-00016.safetensors
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 from modelscope.hub.file_download import model_file_download
#       2 for file_name in file_lis:
# ----> 3     model_dir = model_file_download(model_id='Xunzillm4cc/Xunzi-Qwen1.5-7B_chat',
#       4                                     file_path=file_name,
#       5                                     cache_dir='.qwen',
#       6                                     local_dir='.qwen/Xunzillm4cc/Xunzi-Qwen1.5-7B_chat',
#       7                                     revision='master')
#       8     print(f"Downloaded {file_name} to {model_dir}")
#
# ...
